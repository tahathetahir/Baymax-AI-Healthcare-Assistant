# %% [markdown]
# # WELCOME TO BAYMAX

# %% [markdown]
# ## ALL THE IMPORTANT DEPENDENCIES

# %%
import csv
import pandas as pd
import os

# %% [markdown]
# ### LOADING DATASETS

# %%
file_path = []
file_path.append(os.path.join('Data','description.csv'))
file_path.append(os.path.join('Data','diets.csv'))
file_path.append(os.path.join('Data','final.csv'))
file_path.append(os.path.join('Data','medications.csv'))
file_path.append(os.path.join('Data','precautions.csv'))
file_path.append(os.path.join('Data','workout.csv'))
file_path.append(os.path.join('Data','Diseases_and_Symptoms_dataset.csv'))
file_path.append(os.path.join('Data','DiseaseAndSymptoms.csv'))
file_path.append(os.path.join('Data','Disease precaution.csv'))

DATASET = []

for i in file_path:
    with open(i,mode = 'r') as file:
        data = pd.read_csv(file)
        DATASET.append(data)
# Out:
#                      Disease  \
# 0             Panic Disorder
# 1                  Vaginitis
# 2   Problem During Pregnancy
# 3         Acute Pancreatitis
# 4                     Asthma
# ..                       ...
# 95             Heart Failure
# 96            Conjunctivitis
# 97            Herniated Disk
# 98               Diaper Rash
# 99                    Eczema
#
#                                                  Diet
# 0   ['Magnesium-rich foods (spinach, pumpkin seeds...
# 1   ['Probiotics (yogurt, kefir, sauerkraut)', 'Lo...
# 2   ['Prenatal vitamins (consult doctor)', 'Iron-r...
# 3   ['Low-fat foods (boiled vegetables, lean chick...
# 4   ['Anti-inflammatory foods (blueberries, kale, ...
# ..                                                ...
# 95  ['Low-sodium diet', 'Fluid monitoring', 'Potas...
# 96  ['Vitamin A-rich foods (carrots, spinach)', 'Z...
# 97  ['Anti-inflammatory diet (ginger, leafy greens...
# 98  ['Breastfeeding (for infants)', 'For older bab...
# ...

# %%
for i in DATASET:
    print(list(i.columns))
# Out:
# ['Disease', 'Description']
# ['Disease', 'Diet']
# ['Unnamed: 0', 'disease', 'drug']
# ['Disease', 'Medication']
# ['Disease', 'Precaution_1', 'Precaution_2', 'Precaution_3', 'Precaution_4']
# ['Disease', 'Workouts']
# ...
